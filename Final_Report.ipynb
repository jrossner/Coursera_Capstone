# %% [markdown]
# # Boston vs New York City
# Investigation conducted by Jacob Rossner

# %% [markdown]
# ## Introduction
# The classic Boston versus New York City rivalry thriving today had its roots planted in the early 1600s. The vast difference in religious cultures of European Settlers bred hostility: the Puritan culture of those who settled Massachusetts clashed with the religious freedom promoted in present-day New York. Sporting contests have breathed life into the rivalry; including the New York Yankees meeting the Boston Red Sox in the MLB's World Series, the New England Patriots' stand-offs against the New York Giants in the NFL's Superbowl, and the illustrious history of matchups between the NBA's Boston Celtics and New York Knicks.
#
# There is a culture of disdain for the other city entwined in the blood of each city, so surely they must be nothing like each other? These cities are less than 250 miles apart, so what really separates them? Besides being loyal to their city, how can a person choose their side if they come from outside the competition? Let's use Foursquare's location data to see if the features of neighborhoods in Boston and New York City are different, as well as crime data to see if the cities experience different types of crime.

# %% [markdown]
# ## Data
# I will be using Foursquare location data in conjunction with a New York City crime data set and a Boston crime data set.

# %% [markdown]
# #### Foursquare Data
# Foursquare has built up a massive amount of location data by utilizing crowd-sourced data. People use apps that are powered by Foursquare to "check-in", which effectively gives Foursquare a geospatial point and information on the feature at that point in the form of ratings, reviews, tips, etc. Foursquare claims they register 9 billion places visited a month, and that they boast a database of over 105 million places.
#
# How can we use this data? Well perhaps we'd like to compare the availability of pizza places in both cities, we could use Foursquare data to check out the distribution of businesses in each city with "Pizza" in their name and plot them on a map. Check out process below for creating the maps of all the pizza places within 1 mile of the epicenter of each city.

# %% [markdown]
# First we import the necessary tools.

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     certifi-2020.6.20          |   py36h9f0ad1d_0         151 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     ca-certificates-2020.6.20  |       hecda079_0         145 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          4.1.0-py_1        conda-forge
#     branca:          0.4.1-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     python_abi:      3.6-1_cp36m       conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     certifi:         2020.6.20-py36_0              --> 2020.6.20-py36h9f0ad1d_0 conda-forge
#     openssl:         1.1.1g-h7b6447c_0             --> 1.1.1g-h516909a_0        conda-forge
#
# The following packages will be DOWNGRADED:
#
#     ca-certificates: 2020.6.24-0                   --> 2020.6.20-hecda079_0     conda-forge
#
#
# Downloading and Extracting Packages
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# certifi-2020.6.20    | 151 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# ca-certificates-2020 | 145 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
CLIENT_ID = 'ZFPLKJUYQ4QRIQ54EXFUZIYTDJJMLA341EIHRQW3BTVWRKKU'
CLIENT_SECRET = 'GY5KRZEPMXPQAUSYE0KR50TF4Y1MGEECFDSWG5JA4LWC55IW'
VERSION = '20180604'
LIMIT = 30

# %% [markdown]
# We define the coordinates of the epicenter of each city.

# %%
bos_lat = 42.361145
bos_lon = -71.057083
nyc_lat = 40.730610
nyc_lon = -73.935242

search_query = "Pizza"
radius = 1609.34 # 1609.34 meters in a mile

# %% [markdown]
# And create our url for making calls to the Foursquare servers.

# %%
bos_url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, bos_lat, bos_lon, VERSION, search_query, radius, LIMIT)
nyc_url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, nyc_lat, nyc_lon, VERSION, search_query, radius, LIMIT)

# %% [markdown]
# Here we make our request to the Foursquare servers for the json file of the features near our coordinates.

# %%
bos_results = requests.get(bos_url).json()
nyc_results = requests.get(nyc_url).json()
bos_results, nyc_results
# Out:
# ({'meta': {'code': 200, 'requestId': '5f0e6c6186c2e752a01d3e2d'},
#   'response': {'venues': [{'id': '4c2a2790ce3fc928e9da6f88',
#      'name': "Sal's Pizza",
#      'location': {'address': '150 Tremont St',
#       'crossStreet': 'at West St',
#       'lat': 42.35489042678564,
#       'lng': -71.06351671773069,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 42.35489042678564,
#         'lng': -71.06351671773069}],
#       'distance': 874,
#       'postalCode': '02111',
#       'cc': 'US',
#       'city': 'Boston',
#       'state': 'MA',
#       'country': 'United States',
#       'formattedAddress': ['150 Tremont St (at West St)',
#        'Boston, MA 02111',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4aee268ff964a52086d221e3',
#      'name': 'Boston Kitchen Pizza',
#      'location': {'address': '1 Stuart St',
#       'crossStreet': 'Washington St',
#       'lat': 42.35090194801581,
#       'lng': -71.0630241266923,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 42.35090194801581,
#         'lng': -71.0630241266923}],
#       'distance': 1240,
#       'postalCode': '02116',
#       'cc': 'US',
#       'city': 'Boston',
#       'state': 'MA',
#       'country': 'United States',
#       'formattedAddress': ['1 Stuart St (Washington St)',
#        'Boston, MA 02116',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'delivery': {'id': '1453888',
#       'url': 'https://www.grubhub.com/restaurant/boston-kitchen-pizza-1-stuart-st-boston/1453888?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1453888',
#       'provider': {'name': 'grubhub',
#        'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#         'sizes': [40, 50],
#         'name': '/delivery_provider_grubhub_20180129.png'}}},
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '585ab814e309e16a0cdaab14',
#      'name': 'Blaze Pizza',
#      'location': {'address': '123 Stuart St,',
#       'lat': 42.35104126714644,
#       'lng': -71.06561514885372,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 42.35104126714644,
#         'lng': -71.06561514885372}],
#       'distance': 1325,
#       'postalCode': '02116',
#       'cc': 'US',
#       'city': 'Boston',
#       'state': 'MA',
#       'country': 'United States',
#       'formattedAddress': ['123 Stuart St,',
#        'Boston, MA 02116',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4bcf44d5462cb713715fd607',
#      'name': "Caesar's Pizza & Subs",
#      'location': {'address': '34 Essex St',
#       'lat': 42.352786,
#       'lng': -71.061981,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 42.352786,
#         'lng': -71.061981},
#        {'label': 'entrance', 'lat': 42.352513, 'lng': -71.061954}],
#       'distance': 1013,
#       'postalCode': '02111',
#       'cc': 'US',
#       'city': 'Boston',
#       'state': 'MA',
#       'country': 'United States',
#       'formattedAddress': ['34 Essex St',
#        'Boston, MA 02111',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '56290ddd498e3a8dc65d6a55',
#      'name': 'Oath Pizza - South Station',
#      'location': {'address': '700 Atlantic Ave',
#       'crossStreet': 'at Summer St',
#       'lat': 42.351511792478014,
#       'lng': -71.05504137298902,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 42.351511792478014,
#         'lng': -71.05504137298902}],
#       'distance': 1085,
#       'postalCode': '02111',
#       'cc': 'US',
#       'city': 'Boston',
#       'state': 'MA',
#       'country': 'United States',
#       'formattedAddress': ['700 Atlantic Ave (at Summer St)',
#        'Boston, MA 02111',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4b8dd656f964a520fd0f33e3',
#      'name': "Adam's Pizza",
#      'location': {'address': '120 Blackstone St',
#       'lat': 42.361592,
#       'lng': -71.056545,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 42.361592,
#         'lng': -71.056545},
#        {'label': 'entrance', 'lat': 42.36187, 'lng': -71.056726}],
#       'distance': 66,
#       'postalCode': '02109',
#       'cc': 'US',
#       'city': 'Boston',
#       'state': 'MA',
#       'country': 'United States',
#       'formattedAddress': ['120 Blackstone St',
#        'Boston, MA 02109',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4a45bd0af964a52079a81fe3',
#      'name': 'New York Pizza - Theater District',
#      'location': {'address': '224 Tremont St',
#       'crossStreet': 'btwn Boylston & Stuart',
#       'lat': 42.351332035941105,
#       'lng': -71.0647529961542,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 42.351332035941105,
#         'lng': -71.0647529961542}],
#       'distance': 1261,
#       'postalCode': '02116',
#       'cc': 'US',
#       'city': 'Boston',
#       'state': 'MA',
#       'country': 'United States',
#       'formattedAddress': ['224 Tremont St (btwn Boylston & Stuart)',
#        'Boston, MA 02116',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'delivery': {'id': '302541',
#       'url': 'https://www.grubhub.com/restaurant/new-york-pizza-224-tremont-st-boston/302541?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=302541',
#       'provider': {'name': 'grubhub',
#        'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#         'sizes': [40, 50],
#         'name': '/delivery_provider_grubhub_20180129.png'}}},
#      'venuePage': {'id': '476606438'},
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4aa98799f964a5201a5420e3',
#      'name': 'Haymarket Pizza',
#      'location': {'address': '106 Blackstone St.',
#       'crossStreet': 'btwn Hanover & North',
#       'lat': 42.361601889125694,
#       'lng': -71.05646546782602,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 42.361601889125694,
#         'lng': -71.05646546782602},
#        {'label': 'entrance', 'lat': 42.361703, 'lng': -71.056535}],
#       'distance': 71,
#       'postalCode': '02109',
#       'cc': 'US',
#       'city': 'Boston',
#       'state': 'MA',
#       'country': 'United States',
#       'formattedAddress': ['106 Blackstone St. (btwn Hanover & North)',
#        'Boston, MA 02109',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4accca58f964a52087c920e3',
#      'name': "Ernesto's Pizza",
#      'location': {'address': '69 Salem St',
#       'crossStreet': 'btwn Morton & Stillman',
#       'lat': 42.36337010778569,
#       'lng': -71.05599795301806,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 42.36337010778569,
#         'lng': -71.05599795301806},
#        {'label': 'entrance', 'lat': 42.363396, 'lng': -71.055936}],
#       'distance': 263,
#       'postalCode': '02113',
#       'cc': 'US',
#       'city': 'Boston',
#       'state': 'MA',
#       'country': 'United States',
#       'formattedAddress': ['69 Salem St (btwn Morton & Stillman)',
#        'Boston, MA 02113',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'delivery': {'id': '299737',
#       'url': 'https://www.grubhub.com/restaurant/ernestos-69-salem-st-boston/299737?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=299737',
#       'provider': {'name': 'grubhub',
#        'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#         'sizes': [40, 50],
#         'name': '/delivery_provider_grubhub_20180129.png'}}},
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4b5f20ebf964a520bba729e3',
#      'name': 'Rome Pizza',
#      'location': {'address': '416 Tremont St',
#       'lat': 42.3468325766716,
#       'lng': -71.06894307740059,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 42.3468325766716,
#         'lng': -71.06894307740059},
#        {'label': 'entrance', 'lat': 42.346857, 'lng': -71.06872}],
#       'distance': 1868,
#       'postalCode': '02116',
#       'cc': 'US',
#       'city': 'Boston',
#       'state': 'MA',
#       'country': 'United States',
#       'formattedAddress': ['416 Tremont St',
#        'Boston, MA 02116',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'delivery': {'id': '55406',
#       'url': 'https://www.grubhub.com/restaurant/rome-pizza-416-tremont-st-boston/55406?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=55406',
#       'provider': {'name': 'grubhub',
#        'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#         'sizes': [40, 50],
#         'name': '/delivery_provider_grubhub_20180129.png'}}},
#      'venuePage': {'id': '90049969'},
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4ae8bf2ef964a520ebb121e3',
#      'name': 'Halftime Pizza',
#      'location': {'address': '115 Causeway St',
#       'crossStreet': 'at Friend St.',
#       'lat': 42.36519426394752,
#       'lng': -71.06174741425218,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 42.36519426394752,
#         'lng': -71.06174741425218},
#        {'label': 'entrance', 'lat': 42.365139, 'lng': -71.061533}],
#       'distance': 591,
#       'postalCode': '02114',
#       'cc': 'US',
#       'city': 'Boston',
#       'state': 'MA',
#       'country': 'United States',
#       'formattedAddress': ['115 Causeway St (at Friend St.)',
#        'Boston, MA 02114',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '5287a20411d2a7ff9cc0351d',
#      'name': 'Crush Pizza',
#      'location': {'address': '107 State St',
#       'lat': 42.359068082160164,
#       'lng': -71.05492253113808,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 42.359068082160164,
#         'lng': -71.05492253113808},
#        {'label': 'entrance', 'lat': 42.35908, 'lng': -71.055002}],
#       'distance': 291,
#       'postalCode': '02109',
#       'cc': 'US',
#       'city': 'Boston',
#       'state': 'MA',
#       'country': 'United States',
#       'formattedAddress': ['107 State St',
#        'Boston, MA 02109',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'delivery': {'id': '295803',
#       'url': 'https://www.grubhub.com/restaurant/crush-pizza-107-state-st-boston/295803?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=295803',
#       'provider': {'name': 'grubhub',
#        'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#         'sizes': [40, 50],
#         'name': '/delivery_provider_grubhub_20180129.png'}}},
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '55d2746a498ead80bbc74e6b',
#      'name': 'pizza corner in the prado',
#      'location': {'lat': 42.36592964456448,
#       'lng': -71.05396404170354,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 42.36592964456448,
#         'lng': -71.05396404170354}],
#       'distance': 591,
#       'cc': 'US',
#       'city': 'Boston',
#       'state': 'MA',
#       'country': 'United States',
#       'formattedAddress': ['Boston, MA', 'United States']},
#      'categories': [{'id': '52e81612bcbc57f1066b7a21',
#        'name': 'National Park',
#        'pluralName': 'National Parks',
#        'shortName': 'National Park',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4e4c36abbd413c4cc667c1ec',
#      'name': 'Pizza Oggi',
#      'location': {'address': '131 Broad St',
#       'lat': 42.35715866088867,
#       'lng': -71.05223083496094,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 42.35715866088867,
#         'lng': -71.05223083496094}],
#       'distance': 596,
#       'postalCode': '02110',
#       'cc': 'US',
#       'city': 'Boston',
#       'state': 'MA',
#       'country': 'United States',
#       'formattedAddress': ['131 Broad St',
#        'Boston, MA 02110',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4f328e5e19836c91c7e35619',
#      'name': 'Pizza in Piazza',
#      'location': {'address': '283 Causeway St',
#       'lat': 42.366981506347656,
#       'lng': -71.05818176269531,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 42.366981506347656,
#         'lng': -71.05818176269531}],
#       'distance': 655,
#       'postalCode': '02114',
#       'cc': 'US',
#       'city': 'Boston',
#       'state': 'MA',
#       'country': 'United States',
#       'formattedAddress': ['283 Causeway St',
#        'Boston, MA 02114',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '578841f2498e37a82f380acf',
#      'name': 'Boston Pizza Tours',
#      'location': {'address': '71 Commercial St',
#       'crossStreet': 'near Cross Steet',
#       'lat': 42.3612912,
#       'lng': -71.0529957,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 42.3612912,
#         'lng': -71.0529957}],
#       'distance': 336,
#       'postalCode': '02109',
#       'cc': 'US',
#       'city': 'Boston',
#       'state': 'MA',
#       'country': 'United States',
#       'formattedAddress': ['71 Commercial St (near Cross Steet)',
#        'Boston, MA 02109',
#        'United States']},
#      'categories': [{'id': '4f4530164b9074f6e4fb00ff',
#        'name': 'Tourist Information Center',
#        'pluralName': 'Tourist Information Centers',
#        'shortName': 'Tourist Information',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/touristinformation_',
#         'suffix': '.png'},
#        'primary': True}],
#      'venuePage': {'id': '217001766'},
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '55bd997f498e0546eb9d031d',
#      'name': "Nonno's Pizza",
#      'location': {'lat': 42.364432,
#       'lng': -71.061279,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 42.364432,
#         'lng': -71.061279},
#        {'label': 'entrance', 'lat': 42.364507, 'lng': -71.061172}],
#       'distance': 502,
#       'cc': 'US',
#       'city': 'Boston',
#       'state': 'MA',
#       'country': 'United States',
#       'formattedAddress': ['Boston, MA', 'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4c07e2e2a1b32d7f392095f0',
#      'name': 'Bostone Pizza',
#      'location': {'address': '102 Water St',
#       'lat': 42.358049804539334,
#       'lng': -71.05497032645424,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 42.358049804539334,
#         'lng': -71.05497032645424},
#        {'label': 'entrance', 'lat': 42.358077, 'lng': -71.054956}],
#       'distance': 385,
#       'postalCode': '02109',
#       'cc': 'US',
#       'city': 'Boston',
#       'state': 'MA',
#       'country': 'United States',
#       'formattedAddress': ['102 Water St',
#        'Boston, MA 02109',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4f3ae904e4b08082ad9f0edf',
#      'name': 'West end pizza',
#      'location': {'lat': 42.364432,
#       'lng': -71.061279,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 42.364432,
#         'lng': -71.061279},
#        {'label': 'entrance', 'lat': 42.364507, 'lng': -71.061172}],
#       'distance': 502,
#       'postalCode': '02114',
#       'cc': 'US',
#       'city': 'Boston',
#       'state': 'MA',
#       'country': 'United States',
#       'formattedAddress': ['Boston, MA 02114', 'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'delivery': {'id': '1456633',
#       'url': 'https://www.grubhub.com/restaurant/west-end-pizza-252-friend-street-boston/1456633?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1456633',
#       'provider': {'name': 'grubhub',
#        'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#         'sizes': [40, 50],
#         'name': '/delivery_provider_grubhub_20180129.png'}}},
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4b6c4a4bf964a520352e2ce3',
#      'name': "Domino's Pizza",
#      'location': {'address': '64 Staniford St',
#       'crossStreet': 'Merrimac St',
#       'lat': 42.36285766489993,
#       'lng': -71.06417256022723,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 42.36285766489993,
#         'lng': -71.06417256022723},
#        {'label': 'entrance', 'lat': 42.362485, 'lng': -71.064141}],
#       'distance': 613,
#       'postalCode': '02114',
#       'cc': 'US',
#       'city': 'Boston',
#       'state': 'MA',
#       'country': 'United States',
#       'formattedAddress': ['64 Staniford St (Merrimac St)',
#        'Boston, MA 02114',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '559738db498eb21cdd6a86f1',
#      'name': "Nanoo's Pizza",
#      'location': {'lat': 42.36541458465564,
#       'lng': -71.06121258239025,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 42.36541458465564,
#         'lng': -71.06121258239025}],
#       'distance': 584,
#       'cc': 'US',
#       'city': 'Boston',
#       'state': 'MA',
#       'country': 'United States',
#       'formattedAddress': ['Boston, MA', 'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '51aa1142498ebb2eeda4386a',
#      'name': 'Boston Pizza Tour',
#      'location': {'address': 'Hanover Street',
#       'crossStreet': 'Cross Street',
#       'lat': 42.36643269563486,
#       'lng': -71.05465466078722,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 42.36643269563486,
#         'lng': -71.05465466078722}],
#       'distance': 621,
#       'cc': 'US',
#       'city': 'Boston',
#       'state': 'MA',
#       'country': 'United States',
#       'formattedAddress': ['Hanover Street (Cross Street)',
#        'Boston, MA',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1f6931735',
#        'name': 'General Travel',
#        'pluralName': 'General Travel',
#        'shortName': 'Travel',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/default_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '513bb5aa72da99bd5074bb57',
#      'name': 'Pastoral - Artisan Pizza + Kitchen and Bar',
#      'location': {'address': '345 Congress St',
#       'crossStreet': 'Fort Point',
#       'lat': 42.35076030186295,
#       'lng': -71.04902256856386,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 42.35076030186295,
#         'lng': -71.04902256856386}],
#       'distance': 1332,
#       'postalCode': '02210',
#       'cc': 'US',
#       'neighborhood': 'Fort Point',
#       'city': 'Boston',
#       'state': 'MA',
#       'country': 'United States',
#       'formattedAddress': ['345 Congress St (Fort Point)',
#        'Boston, MA 02210',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'venuePage': {'id': '54570248'},
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4f4bc285e4b0a34d3b055fa9',
#      'name': "Papa's Roast Beef & Pizza",
#      'location': {'address': '55 Causeway St',
#       'lat': 42.364578986248596,
#       'lng': -71.06320324558348,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 42.364578986248596,
#         'lng': -71.06320324558348},
#        {'label': 'entrance', 'lat': 42.364345, 'lng': -71.062998}],
#       'distance': 632,
#       'postalCode': '02114',
#       'cc': 'US',
#       'city': 'Boston',
#       'state': 'MA',
#       'country': 'United States',
#       'formattedAddress': ['55 Causeway St',
#        'Boston, MA 02114',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '5168cc41e4b0429728c3ec0b',
#      'name': '1/2 Time Pizza',
#      'location': {'address': 'Causeway Street',
#       'lat': 42.365749,
#       'lng': -71.062237,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 42.365749,
#         'lng': -71.062237}],
#       'distance': 665,
#       'cc': 'US',
#       'city': 'Boston',
#       'state': 'MA',
#       'country': 'United States',
#       'formattedAddress': ['Causeway Street', 'Boston, MA', 'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4f3271de19836c91c7d879c2',
#      'name': 'Pacinis Pizza and Italian Eatery',
#      'location': {'address': '74 Summer St',
#       'lat': 42.354051,
#       'lng': -71.058406,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 42.354051,
#         'lng': -71.058406}],
#       'distance': 797,
#       'postalCode': '02110',
#       'cc': 'US',
#       'city': 'Boston',
#       'state': 'MA',
#       'country': 'United States',
#       'formattedAddress': ['74 Summer St',
#        'Boston, MA 02110',
#        'United States']},
#      'categories': [{'id': '4d4b7105d754a06374d81259',
#        'name': 'Food',
#        'pluralName': 'Food',
#        'shortName': 'Food',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4696393cf964a520e2481fe3',
#      'name': 'The Esplanade',
#      'location': {'address': 'The Esplanade',
#       'lat': 42.35606380136848,
#       'lng': -71.0748942990867,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 42.35606380136848,
#         'lng': -71.0748942990867}],
#       'distance': 1570,
#       'postalCode': '02114',
#       'cc': 'US',
#       'city': 'Boston',
#       'state': 'MA',
#       'country': 'United States',
#       'formattedAddress': ['The Esplanade',
#        'Boston, MA 02114',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d163941735',
#        'name': 'Park',
#        'pluralName': 'Parks',
#        'shortName': 'Park',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '500c000fe4b0c2a4e08f9f78',
#      'name': 'Pizza Corner',
#      'location': {'address': 'Cambridge City Square, 1st Floor',
#       'lat': 42.372059,
#       'lng': -71.0615968,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 42.372059,
#         'lng': -71.0615968}],
#       'distance': 1270,
#       'postalCode': '02129',
#       'cc': 'US',
#       'city': 'Medan',
#       'state': 'MA',
#       'country': 'United States',
#       'formattedAddress': ['Cambridge City Square, 1st Floor',
#        'Medan, MA 02129',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4cc6f05942d1b60cc0262c13',
#      'name': 'Jay Bo Pizza',
#      'location': {'address': '48 Winter St',
#       'crossStreet': 'Tremont St.',
#       'lat': 42.35590744018555,
#       'lng': -71.06196594238281,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 42.35590744018555,
#         'lng': -71.06196594238281}],
#       'distance': 708,
#       'postalCode': '02108',
#       'cc': 'US',
#       'city': 'Boston',
#       'state': 'MA',
#       'country': 'United States',
#       'formattedAddress': ['48 Winter St (Tremont St.)',
#        'Boston, MA 02108',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '584b4f009343e03b166250d0',
#      'name': 'All Star Pizza Bar',
#      'location': {'address': '204 Cambridge St',
#       'lat': 42.36117553076586,
#       'lng': -71.06591493617547,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 42.36117553076586,
#         'lng': -71.06591493617547}],
#       'distance': 726,
#       'postalCode': '02114',
#       'cc': 'US',
#       'city': 'Boston',
#       'state': 'MA',
#       'country': 'United States',
#       'formattedAddress': ['204 Cambridge St',
#        'Boston, MA 02114',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False}]}},
#  {'meta': {'code': 200, 'requestId': '5f0e6d2f0f668a375cd1f0f3'},
#   'response': {'venues': [{'id': '4f77e3d9e4b06ff836a5b1d9',
#      'name': 'Pizza Prince',
#      'location': {'address': '86 Nassau Ave',
#       'crossStreet': 'Manhattan Ave.',
#       'lat': 40.72389912120655,
#       'lng': -73.95052951530391,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 40.72389912120655,
#         'lng': -73.95052951530391}],
#       'distance': 1490,
#       'postalCode': '11222',
#       'cc': 'US',
#       'city': 'Brooklyn',
#       'state': 'NY',
#       'country': 'United States',
#       'formattedAddress': ['86 Nassau Ave (Manhattan Ave.)',
#        'Brooklyn, NY 11222',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'delivery': {'id': '270271',
#       'url': 'https://www.seamless.com/menu/pizza-prince-86-nassau-ave-brooklyn/270271?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=270271',
#       'provider': {'name': 'seamless',
#        'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#         'sizes': [40, 50],
#         'name': '/delivery_provider_seamless_20180129.png'}}},
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4ac77b97f964a5207cb720e3',
#      'name': "Marabella's Pizza",
#      'location': {'address': '4107 Greenpoint Ave',
#       'crossStreet': 'at 41st St',
#       'lat': 40.74017373127598,
#       'lng': -73.92391877458819,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 40.74017373127598,
#         'lng': -73.92391877458819}],
#       'distance': 1430,
#       'postalCode': '11104',
#       'cc': 'US',
#       'city': 'Sunnyside',
#       'state': 'NY',
#       'country': 'United States',
#       'formattedAddress': ['4107 Greenpoint Ave (at 41st St)',
#        'Sunnyside, NY 11104',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'delivery': {'id': '304724',
#       'url': 'https://www.seamless.com/menu/marabella-41-07-greenpoint-ave-sunnyside/304724?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=304724',
#       'provider': {'name': 'seamless',
#        'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#         'sizes': [40, 50],
#         'name': '/delivery_provider_seamless_20180129.png'}}},
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4b1451f6f964a52023a123e3',
#      'name': 'L.A. Pizza & Convenience',
#      'location': {'address': '887 Manhattan Ave',
#       'crossStreet': 'Greenpoint Ave',
#       'lat': 40.729910659916285,
#       'lng': -73.95414543863794,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 40.729910659916285,
#         'lng': -73.95414543863794}],
#       'distance': 1596,
#       'postalCode': '11222',
#       'cc': 'US',
#       'city': 'New York',
#       'state': 'NY',
#       'country': 'United States',
#       'formattedAddress': ['887 Manhattan Ave (Greenpoint Ave)',
#        'New York, NY 11222',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4a142410f964a52007781fe3',
#      'name': 'Italy Pizza',
#      'location': {'address': '800 Manhattan Ave',
#       'crossStreet': 'Meserole Ave/Calyer St',
#       'lat': 40.727711857496196,
#       'lng': -73.95305085278082,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 40.727711857496196,
#         'lng': -73.95305085278082},
#        {'label': 'entrance', 'lat': 40.727802, 'lng': -73.952978}],
#       'distance': 1536,
#       'postalCode': '11222',
#       'cc': 'US',
#       'city': 'Brooklyn',
#       'state': 'NY',
#       'country': 'United States',
#       'formattedAddress': ['800 Manhattan Ave (Meserole Ave/Calyer St)',
#        'Brooklyn, NY 11222',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'delivery': {'id': '1134212',
#       'url': 'https://www.seamless.com/menu/italy-pizza-800-manhattan-ave-brooklyn/1134212?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1134212',
#       'provider': {'name': 'seamless',
#        'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#         'sizes': [40, 50],
#         'name': '/delivery_provider_seamless_20180129.png'}}},
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4a63d726f964a520e6c51fe3',
#      'name': "Tony's Pizza & Pasta",
#      'location': {'address': '355 Graham Ave',
#       'crossStreet': 'btwn Metropolitan and Conselyea',
#       'lat': 40.71504374670165,
#       'lng': -73.9444775239192,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 40.71504374670165,
#         'lng': -73.9444775239192},
#        {'label': 'entrance', 'lat': 40.715052, 'lng': -73.944618}],
#       'distance': 1899,
#       'postalCode': '11211',
#       'cc': 'US',
#       'city': 'Brooklyn',
#       'state': 'NY',
#       'country': 'United States',
#       'formattedAddress': ['355 Graham Ave (btwn Metropolitan and Conselyea)',
#        'Brooklyn, NY 11211',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'delivery': {'id': '634314',
#       'url': 'https://www.seamless.com/menu/tonys-pizza-355-graham-ave-brooklyn/634314?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=634314',
#       'provider': {'name': 'seamless',
#        'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#         'sizes': [40, 50],
#         'name': '/delivery_provider_seamless_20180129.png'}}},
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4d48a3ef5241236aef1d6d04',
#      'name': 'Oasis Pizza & Gyro',
#      'location': {'address': '4002 Queens Blvd',
#       'crossStreet': 'at 40th St.',
#       'lat': 40.74354675388641,
#       'lng': -73.9243298302878,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 40.74354675388641,
#         'lng': -73.9243298302878}],
#       'distance': 1709,
#       'postalCode': '11104',
#       'cc': 'US',
#       'city': 'Sunnyside',
#       'state': 'NY',
#       'country': 'United States',
#       'formattedAddress': ['4002 Queens Blvd (at 40th St.)',
#        'Sunnyside, NY 11104',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4c64a131dddfa593912f92ff',
#      'name': 'Taco Bell/Pizza Hut',
#      'location': {'address': '245 Frost St',
#       'crossStreet': 'Woodpoint',
#       'lat': 40.718595,
#       'lng': -73.941025,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 40.718595,
#         'lng': -73.941025},
#        {'label': 'entrance', 'lat': 40.718526, 'lng': -73.941015}],
#       'distance': 1423,
#       'postalCode': '11211',
#       'cc': 'US',
#       'city': 'Brooklyn',
#       'state': 'NY',
#       'country': 'United States',
#       'formattedAddress': ['245 Frost St (Woodpoint)',
#        'Brooklyn, NY 11211',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '5a4ec30dfc9e9447dc924a65',
#      'name': 'Original Pizza and Grill',
#      'location': {'address': '93 Norman Ave',
#       'crossStreet': 'Manhattan Ave',
#       'lat': 40.725639,
#       'lng': -73.951449,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 40.725639,
#         'lng': -73.951449}],
#       'distance': 1474,
#       'postalCode': '11222',
#       'cc': 'US',
#       'city': 'New York',
#       'state': 'NY',
#       'country': 'United States',
#       'formattedAddress': ['93 Norman Ave (Manhattan Ave)',
#        'New York, NY 11222',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'delivery': {'id': '1980797',
#       'url': 'https://www.seamless.com/menu/greenpoint-original-italian-pizza-93-norman-ave-brooklyn/1980797?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1980797',
#       'provider': {'name': 'seamless',
#        'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#         'sizes': [40, 50],
#         'name': '/delivery_provider_seamless_20180129.png'}}},
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4c2c37958abca593ff720120',
#      'name': "Giovanni's Pizza Restaurant",
#      'location': {'address': '47st 47ave',
#       'crossStreet': '47st',
#       'lat': 40.73903077203334,
#       'lng': -73.9190151931811,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 40.73903077203334,
#         'lng': -73.9190151931811}],
#       'distance': 1658,
#       'postalCode': '11377',
#       'cc': 'US',
#       'city': 'New York',
#       'state': 'NY',
#       'country': 'United States',
#       'formattedAddress': ['47st 47ave (47st)',
#        'New York, NY 11377',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d16e941735',
#        'name': 'Fast Food Restaurant',
#        'pluralName': 'Fast Food Restaurants',
#        'shortName': 'Fast Food',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#         'suffix': '.png'},
#        'primary': True}],
#      'delivery': {'id': '305476',
#       'url': 'https://www.seamless.com/menu/giovannis-pizza-restaurant-45-59-47th-st-woodside/305476?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=305476',
#       'provider': {'name': 'seamless',
#        'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#         'sizes': [40, 50],
#         'name': '/delivery_provider_seamless_20180129.png'}}},
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '50c3e2d8e4b0eaecd85a9e6d',
#      'name': 'Pizza House',
#      'location': {'lat': 40.7244861857449,
#       'lng': -73.94043385548419,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 40.7244861857449,
#         'lng': -73.94043385548419}],
#       'distance': 810,
#       'postalCode': '11222',
#       'cc': 'US',
#       'city': 'Brooklyn',
#       'state': 'NY',
#       'country': 'United States',
#       'formattedAddress': ['Brooklyn, NY 11222', 'United States']},
#      'categories': [{'id': '4bf58dd8d48988d123951735',
#        'name': 'Smoke Shop',
#        'pluralName': 'Smoke Shops',
#        'shortName': 'Smoke Shop',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/tobacco_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4bd881550b779c74765407a0',
#      'name': "Papa John's Pizza",
#      'location': {'address': '40-12 Greenpoint Avenue',
#       'crossStreet': '48 ave',
#       'lat': 40.7395438868585,
#       'lng': -73.92464733880382,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 40.7395438868585,
#         'lng': -73.92464733880382}],
#       'distance': 1337,
#       'postalCode': '11104',
#       'cc': 'US',
#       'city': 'Sunnyside',
#       'state': 'NY',
#       'country': 'United States',
#       'formattedAddress': ['40-12 Greenpoint Avenue (48 ave)',
#        'Sunnyside, NY 11104',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'delivery': {'id': '315591',
#       'url': 'https://www.seamless.com/menu/papa-johns-pizza-40-12-greenpoint-ave-sunnyside/315591?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=315591',
#       'provider': {'name': 'seamless',
#        'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#         'sizes': [40, 50],
#         'name': '/delivery_provider_seamless_20180129.png'}}},
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4f32976919836c91c7e6bea5',
#      'name': 'Nassau Pizza and Restaurant',
#      'location': {'address': '253 Nassau Ave',
#       'lat': 40.72608947753906,
#       'lng': -73.94187927246094,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 40.72608947753906,
#         'lng': -73.94187927246094}],
#       'distance': 752,
#       'postalCode': '11222',
#       'cc': 'US',
#       'city': 'Brooklyn',
#       'state': 'NY',
#       'country': 'United States',
#       'formattedAddress': ['253 Nassau Ave',
#        'Brooklyn, NY 11222',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4c0c36c7340720a137608993',
#      'name': 'Pizza-cola Gardens',
#      'location': {'address': '168 Eckford St',
#       'lat': 40.72526,
#       'lng': -73.949389,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 40.72526,
#         'lng': -73.949389},
#        {'label': 'entrance', 'lat': 40.725237, 'lng': -73.949456}],
#       'distance': 1333,
#       'postalCode': '11222',
#       'cc': 'US',
#       'city': 'Brooklyn',
#       'state': 'NY',
#       'country': 'United States',
#       'formattedAddress': ['168 Eckford St',
#        'Brooklyn, NY 11222',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '5d922a7a0dfee2000806920a',
#      'name': 'Pizza Factory',
#      'location': {'lat': 40.742535,
#       'lng': -73.936073,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 40.742535,
#         'lng': -73.936073}],
#       'distance': 1329,
#       'postalCode': '11101',
#       'cc': 'US',
#       'city': 'New York',
#       'state': 'NY',
#       'country': 'United States',
#       'formattedAddress': ['New York, NY 11101', 'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4cddd5f1f8a4a1432bc2d2bc',
#      'name': 'the pizza deal',
#      'location': {'lat': 40.725461,
#       'lng': -73.946124,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 40.725461,
#         'lng': -73.946124}],
#       'distance': 1082,
#       'cc': 'US',
#       'city': 'Brooklyn',
#       'state': 'NY',
#       'country': 'United States',
#       'formattedAddress': ['Brooklyn, NY', 'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4ab947baf964a520c17e20e3',
#      'name': 'Russ Pizza',
#      'location': {'address': '745 Manhattan Ave',
#       'crossStreet': 'btw Norman & Meserole',
#       'lat': 40.72645867309902,
#       'lng': -73.95235989468806,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 40.72645867309902,
#         'lng': -73.95235989468806},
#        {'label': 'entrance', 'lat': 40.726454, 'lng': -73.952426}],
#       'distance': 1516,
#       'postalCode': '11222',
#       'cc': 'US',
#       'city': 'Brooklyn',
#       'state': 'NY',
#       'country': 'United States',
#       'formattedAddress': ['745 Manhattan Ave (btw Norman & Meserole)',
#        'Brooklyn, NY 11222',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'delivery': {'id': '1186726',
#       'url': 'https://www.seamless.com/menu/russ-pizza-745-manhattan-ave-brooklyn/1186726?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1186726',
#       'provider': {'name': 'seamless',
#        'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#         'sizes': [40, 50],
#         'name': '/delivery_provider_seamless_20180129.png'}}},
#      'venuePage': {'id': '94877768'},
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4f3211e819833175d60d8682',
#      'name': 'Pizza Hut',
#      'location': {'address': '208 McGuinness Blvd',
#       'lat': 40.729898,
#       'lng': -73.95056,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 40.729898,
#         'lng': -73.95056}],
#       'distance': 1294,
#       'postalCode': '11222',
#       'cc': 'US',
#       'city': 'Brooklyn',
#       'state': 'NY',
#       'country': 'United States',
#       'formattedAddress': ['208 McGuinness Blvd',
#        'Brooklyn, NY 11222',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '51169d09e4b08a571cc09298',
#      'name': "Kimbo's Pizza Palace",
#      'location': {'lat': 40.72504633220885,
#       'lng': -73.94161063649824,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 40.72504633220885,
#         'lng': -73.94161063649824}],
#       'distance': 819,
#       'postalCode': '11222',
#       'cc': 'US',
#       'city': 'Brooklyn',
#       'state': 'NY',
#       'country': 'United States',
#       'formattedAddress': ['Brooklyn, NY 11222', 'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4bdb1a683904a5939fc5489e',
#      'name': "Vito & Franco's Pizza at Bistro 175",
#      'location': {'address': '175 Nassau Ave.  Brooklyn, NY',
#       'lat': 40.725341796875,
#       'lng': -73.94645690917969,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 40.725341796875,
#         'lng': -73.94645690917969}],
#       'distance': 1113,
#       'cc': 'US',
#       'city': 'Brooklyn',
#       'state': 'NY',
#       'country': 'United States',
#       'formattedAddress': ['175 Nassau Ave.  Brooklyn, NY',
#        'Brooklyn, NY',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4a79ba66f964a52078e71fe3',
#      'name': "Baldo's Pizza",
#      'location': {'address': '175 Nassau Ave',
#       'lat': 40.725341796875,
#       'lng': -73.94645690917969,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 40.725341796875,
#         'lng': -73.94645690917969}],
#       'distance': 1113,
#       'postalCode': '11222',
#       'cc': 'US',
#       'city': 'New York',
#       'state': 'NY',
#       'country': 'United States',
#       'formattedAddress': ['175 Nassau Ave',
#        'New York, NY 11222',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4f32abc719836c91c7ee63f1',
#      'name': 'Primo Pizza',
#      'location': {'address': '212 McGuinness Blvd',
#       'lat': 40.729898,
#       'lng': -73.95056,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 40.729898,
#         'lng': -73.95056},
#        {'label': 'entrance', 'lat': 40.729812, 'lng': -73.950686}],
#       'distance': 1294,
#       'postalCode': '11222',
#       'cc': 'US',
#       'city': 'Brooklyn',
#       'state': 'NY',
#       'country': 'United States',
#       'formattedAddress': ['212 McGuinness Blvd',
#        'Brooklyn, NY 11222',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4b82a08ff964a52062db30e3',
#      'name': 'Blinks Deli & Pizza',
#      'location': {'address': '43-01 35th St',
#       'lat': 40.74612417342374,
#       'lng': -73.92935988447306,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 40.74612417342374,
#         'lng': -73.92935988447306}],
#       'distance': 1796,
#       'postalCode': '11101',
#       'cc': 'US',
#       'city': 'Queens',
#       'state': 'NY',
#       'country': 'United States',
#       'formattedAddress': ['43-01 35th St',
#        'Long Island City, NY 11101',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d14e941735',
#        'name': 'American Restaurant',
#        'pluralName': 'American Restaurants',
#        'shortName': 'American',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#         'suffix': '.png'},
#        'primary': True}],
#      'delivery': {'id': '993214',
#       'url': 'https://www.seamless.com/menu/blinks-deli--pizzeria-4301-35th-st-long-island-city/993214?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=993214',
#       'provider': {'name': 'seamless',
#        'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#         'sizes': [40, 50],
#         'name': '/delivery_provider_seamless_20180129.png'}}},
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4bc0ba9c461576b05ea17a32',
#      'name': 'Piazza Pizza',
#      'location': {'address': '3909 47th Ave',
#       'lat': 40.74216825628229,
#       'lng': -73.92603636593213,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 40.74216825628229,
#         'lng': -73.92603636593213}],
#       'distance': 1502,
#       'postalCode': '11104',
#       'cc': 'US',
#       'city': 'Sunnyside',
#       'state': 'NY',
#       'country': 'United States',
#       'formattedAddress': ['3909 47th Ave',
#        'Sunnyside, NY 11104',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4cb66ca656fca1cdb9825618',
#      'name': 'Franklin Pizza',
#      'location': {'address': '109 Franklin St',
#       'crossStreet': 'at Greenpoint Ave',
#       'lat': 40.72976293398734,
#       'lng': -73.9575295235117,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 40.72976293398734,
#         'lng': -73.9575295235117},
#        {'label': 'entrance', 'lat': 40.729667, 'lng': -73.957688}],
#       'distance': 1882,
#       'postalCode': '11222',
#       'cc': 'US',
#       'city': 'Brooklyn',
#       'state': 'NY',
#       'country': 'United States',
#       'formattedAddress': ['109 Franklin St (at Greenpoint Ave)',
#        'Brooklyn, NY 11222',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'delivery': {'id': '228019',
#       'url': 'https://www.seamless.com/menu/franklin-pizza-109-franklin-st-brooklyn/228019?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=228019',
#       'provider': {'name': 'seamless',
#        'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#         'sizes': [40, 50],
#         'name': '/delivery_provider_seamless_20180129.png'}}},
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4d2a8057915fa0932a8e0f0a',
#      'name': 'Little Italy Pizza',
#      'location': {'lat': 40.72318358701643,
#       'lng': -73.9473394487091,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 40.72318358701643,
#         'lng': -73.9473394487091}],
#       'distance': 1313,
#       'cc': 'US',
#       'state': 'New York',
#       'country': 'United States',
#       'formattedAddress': ['New York', 'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4fbbcbc0a17c3adc646fcc55',
#      'name': 'Pizza Menus',
#      'location': {'address': '52-08 Grand Ave',
#       'lat': 40.717430114746094,
#       'lng': -73.91615295410156,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 40.717430114746094,
#         'lng': -73.91615295410156}],
#       'distance': 2178,
#       'postalCode': '11378',
#       'cc': 'US',
#       'city': 'Maspeth',
#       'state': 'NY',
#       'country': 'United States',
#       'formattedAddress': ['52-08 Grand Ave',
#        'Maspeth, NY 11378',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1f4941735',
#        'name': 'Design Studio',
#        'pluralName': 'Design Studios',
#        'shortName': 'Design',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/design_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4f32508319836c91c7cb8f20',
#      'name': 'Original St Marks Pizza',
#      'location': {'address': '86 Nassau Ave',
#       'lat': 40.7237663269043,
#       'lng': -73.95040893554688,
#       'labeledLatLngs': [{'label': 'entrance',
#         'lat': 40.723769,
#         'lng': -73.950524},
#        {'label': 'display',
#         'lat': 40.7237663269043,
#         'lng': -73.95040893554688}],
#       'distance': 1489,
#       'postalCode': '11222',
#       'cc': 'US',
#       'city': 'Brooklyn',
#       'state': 'NY',
#       'country': 'United States',
#       'formattedAddress': ['86 Nassau Ave',
#        'Brooklyn, NY 11222',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4f326f2919836c91c7d76f2f',
#      'name': 'A Taste of Italy Pizza',
#      'location': {'address': '3909 47th Ave',
#       'lat': 40.742210388183594,
#       'lng': -73.92607879638672,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 40.742210388183594,
#         'lng': -73.92607879638672}],
#       'distance': 1504,
#       'postalCode': '11104',
#       'cc': 'US',
#       'city': 'Sunnyside',
#       'state': 'NY',
#       'country': 'United States',
#       'formattedAddress': ['3909 47th Ave',
#        'Sunnyside, NY 11104',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4c6438e72a58c9b68b923461',
#      'name': "Zizi's Pizza",
#      'location': {'address': '30-15 Thomson Ave',
#       'crossStreet': '30th Place',
#       'lat': 40.745335822404016,
#       'lng': -73.93457854611822,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 40.745335822404016,
#         'lng': -73.93457854611822}],
#       'distance': 1640,
#       'postalCode': '11101',
#       'cc': 'US',
#       'city': 'Queens',
#       'state': 'NY',
#       'country': 'United States',
#       'formattedAddress': ['30-15 Thomson Ave (30th Place)',
#        'Long Island City, NY 11101',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False},
#     {'id': '4bc114b9461576b0e3687b32',
#      'name': 'Valdiano Restaurant & Pizza',
#      'location': {'address': '659 Manhattan Ave',
#       'crossStreet': 'btw Bedford & Norman',
#       'lat': 40.72461,
#       'lng': -73.951276,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 40.72461,
#         'lng': -73.951276},
#        {'label': 'entrance', 'lat': 40.724531, 'lng': -73.951343}],
#       'distance': 1508,
#       'postalCode': '11222',
#       'cc': 'US',
#       'city': 'Brooklyn',
#       'state': 'NY',
#       'country': 'United States',
#       'formattedAddress': ['659 Manhattan Ave (btw Bedford & Norman)',
#        'Brooklyn, NY 11222',
#        'United States']},
#      'categories': [{'id': '4bf58dd8d48988d110941735',
#        'name': 'Italian Restaurant',
#        'pluralName': 'Italian Restaurants',
#        'shortName': 'Italian',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#         'suffix': '.png'},
#        'primary': True}],
#      'referralId': 'v-1594781226',
#      'hasPerk': False}]}})

# %%
# assign relevant part of JSON to venues
bos_venues = bos_results['response']['venues']
nyc_venues = nyc_results['response']['venues']

# tranform venues into a dataframe
bos_df = json_normalize(bos_venues)
nyc_df = json_normalize(nyc_venues)

# %% [markdown]
# And we can check out the dataframes populated by pizza venues...

# %%
# keep only columns that include venue name, and anything that is associated with location
bos_filtered_columns = ['name', 'categories'] + [col for col in bos_df.columns if col.startswith('location.')] + ['id']
bos_dataframe_filtered = bos_df.loc[:, bos_filtered_columns]
nyc_filtered_columns = ['name', 'categories'] + [col for col in nyc_df.columns if col.startswith('location.')] + ['id']
nyc_dataframe_filtered = nyc_df.loc[:, nyc_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
bos_dataframe_filtered['categories'] = bos_dataframe_filtered.apply(get_category_type, axis=1)
nyc_dataframe_filtered['categories'] = nyc_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
bos_dataframe_filtered.columns = [column.split('.')[-1] for column in bos_dataframe_filtered.columns]
nyc_dataframe_filtered.columns = [column.split('.')[-1] for column in nyc_dataframe_filtered.columns]

bos_dataframe_filtered.head(), nyc_dataframe_filtered.head()
# Out:
# (                         name   categories           address  cc    city  \
#  0                 Sal's Pizza  Pizza Place    150 Tremont St  US  Boston
#  1        Boston Kitchen Pizza  Pizza Place       1 Stuart St  US  Boston
#  2                 Blaze Pizza  Pizza Place    123 Stuart St,  US  Boston
#  3       Caesar's Pizza & Subs  Pizza Place       34 Essex St  US  Boston
#  4  Oath Pizza - South Station  Pizza Place  700 Atlantic Ave  US  Boston
#
#           country    crossStreet  distance  \
#  0  United States     at West St       874
#  1  United States  Washington St      1240
#  2  United States            NaN      1325
#  3  United States            NaN      1013
#  4  United States   at Summer St      1085
#
#                                      formattedAddress  \
#  0  [150 Tremont St (at West St), Boston, MA 02111...
#  1  [1 Stuart St (Washington St), Boston, MA 02116...
#  2  [123 Stuart St,, Boston, MA 02116, United States]
#  3     [34 Essex St, Boston, MA 02111, United States]
#  4  [700 Atlantic Ave (at Summer St), Boston, MA 0...
#
#                                        labeledLatLngs        lat        lng  \
#  0  [{'label': 'display', 'lat': 42.35489042678564...  42.354890 -71.063517
#  1  [{'label': 'display', 'lat': 42.35090194801581...  42.350902 -71.063024
#  2  [{'label': 'display', 'lat': 42.35104126714644...  42.351041 -71.065615
#  3  [{'label': 'display', 'lat': 42.352786, 'lng':...  42.352786 -71.061981
#  4  [{'label': 'display', 'lat': 42.35151179247801...  42.351512 -71.055041
#
#    neighborhood postalCode state                        id
#  0          NaN      02111    MA  4c2a2790ce3fc928e9da6f88
#  1          NaN      02116    MA  4aee268ff964a52086d221e3
#  2          NaN      02116    MA  585ab814e309e16a0cdaab14
#  3          NaN      02111    MA  4bcf44d5462cb713715fd607
#  4          NaN      02111    MA  56290ddd498e3a8dc65d6a55  ,
#                         name   categories              address  cc       city  \
#  0              Pizza Prince  Pizza Place        86 Nassau Ave  US   Brooklyn
#  1         Marabella's Pizza  Pizza Place  4107 Greenpoint Ave  US  Sunnyside
#  2  L.A. Pizza & Convenience  Pizza Place    887 Manhattan Ave  US   New York
#  3               Italy Pizza  Pizza Place    800 Manhattan Ave  US   Brooklyn
#  4      Tony's Pizza & Pasta  Pizza Place       355 Graham Ave  US   Brooklyn
#
#           country                      crossStreet  distance  \
#  0  United States                   Manhattan Ave.      1490
#  1  United States                       at 41st St      1430
#  2  United States                   Greenpoint Ave      1596
#  3  United States           Meserole Ave/Calyer St      1536
#  4  United States  btwn Metropolitan and Conselyea      1899
#
#                                      formattedAddress  \
#  0  [86 Nassau Ave (Manhattan Ave.), Brooklyn, NY ...
#  1  [4107 Greenpoint Ave (at 41st St), Sunnyside, ...
#  2  [887 Manhattan Ave (Greenpoint Ave), New York,...
#  3  [800 Manhattan Ave (Meserole Ave/Calyer St), B...
#  4  [355 Graham Ave (btwn Metropolitan and Consely...
#
#                                        labeledLatLngs        lat        lng  \
#  0  [{'label': 'display', 'lat': 40.72389912120655...  40.723899 -73.950530
#  1  [{'label': 'display', 'lat': 40.74017373127598...  40.740174 -73.923919
#  2  [{'label': 'display', 'lat': 40.72991065991628...  40.729911 -73.954145
#  3  [{'label': 'display', 'lat': 40.72771185749619...  40.727712 -73.953051
#  4  [{'label': 'display', 'lat': 40.71504374670165...  40.715044 -73.944478
#
#    postalCode state                        id
#  0      11222    NY  4f77e3d9e4b06ff836a5b1d9
#  1      11104    NY  4ac77b97f964a5207cb720e3
#  2      11222    NY  4b1451f6f964a52023a123e3
#  3      11222    NY  4a142410f964a52007781fe3
#  4      11211    NY  4a63d726f964a520e6c51fe3  )

# %% [markdown]
# Now lets plot the pizza places we've found on Folium maps using these data frames.

# %% [markdown]
# ##### Pizza places within 1 mile of the epicenter of Boston

# %%
bos_venues_map = folium.Map(location=[bos_lat, bos_lon], zoom_start=14)

for lat, lng, label in zip(bos_dataframe_filtered.lat, bos_dataframe_filtered.lng, bos_dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(bos_venues_map)

bos_venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##### Pizza places within 1 mile of the epicenter of New York City

# %%
nyc_venues_map = folium.Map(location=[nyc_lat, nyc_lon], zoom_start=14)

for lat, lng, label in zip(nyc_dataframe_filtered.lat, nyc_dataframe_filtered.lng, nyc_dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='green',
        popup=label,
        fill = True,
        fill_color='green',
        fill_opacity=0.6
    ).add_to(nyc_venues_map)

nyc_venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### New York City Crime Data
# The New York City crime data set includes felony, misdemeanor, and violations of city laws reported to the New York City Police Department. The data comes from NYC Open Data, a program supported by the partnership of New York's civic intelligence center (know as The Mayor's Office of Data Analystics or MODA) and The New York City Department of Information Technology and Telecommunications (DoITT).  The original data set, which can be found at this link:
# https://data.cityofnewyork.us/Public-Safety/NYPD-Complaint-Data-Current-Year-To-Date-/5uac-w243,
# contains over 108,000 observations and 35 variables. Each observation is a complaint reported to the New York City Police Department (NYPD).
#
# It is important to note that this data set contains only officially reported complaints to the NYPD, and does not contain any information on if the reported crime was verified as legitimate, nor if any further actions were pursued by the person(s) who reported the crime. There may also be multiple complaints stemming from the same incident; if in a single act a person assaults a homeowner and burglarizes their home, this would likely have been recorded as separate complaints: at least one for the act of assault, and one for the act of burglary.
#
# I am using this data set as a representation of the prevalence of crime in New York City neighborhoods. The original data set contains complaints from 1919 through 2020, but I have reduced the data set to complaints reported in 2018. This was done in the interest of making comparisons to Boston crime and adhereing to maximum file sizes accomodated by Github. Our pared-down dataset contains 229 complaints.

# %%
nyc = pd.read_csv("https://raw.githubusercontent.com/jrossner/Coursera_Capstone/master/NYPD_crime2018.csv", error_bad_lines=False)
nyc.head()
# Out:
#    CMPLNT_NUM  ADDR_PCT_CD    BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT  \
# 0   981432964          105     QUEENS   05/24/2018     12:00:00          NaN
# 1   358551291           84   BROOKLYN   11/01/2018     08:00:00   11/30/2019
# 2   151755406           88   BROOKLYN   12/28/2018     17:00:00   03/31/2020
# 3   625737137           41      BRONX   10/01/2018     07:00:00   11/08/2019
# 4   899799765           23  MANHATTAN   04/01/2018     00:00:00   04/01/2018
#
#   CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  ...  SUSP_SEX  \
# 0          NaN        COMPLETED        NaN          NaN  ...         U
# 1     16:00:00        COMPLETED        NaN          NaN  ...       NaN
# 2     17:12:00        COMPLETED        NaN          NaN  ...         M
# 3     15:00:00        COMPLETED        NaN          NaN  ...       NaN
# 4     00:00:00        COMPLETED        NaN        672.0  ...         U
#
#   TRANSIT_DISTRICT  VIC_AGE_GROUP VIC_RACE VIC_SEX X_COORD_CD  Y_COORD_CD  \
# 0              NaN          45-64    WHITE       F    1056840      205482
# 1              NaN          25-44    WHITE       F     984377      191776
# 2              NaN          25-44    WHITE       F     992826      192283
# 3              NaN          18-24    BLACK       F    1013232      236725
# 4              NaN          25-44    BLACK       F     999243      227082
#
#     Latitude  Longitude                                   Lat_Lon
# 0  40.730388 -73.738089   (40.73038766700005, -73.73808927199997)
# 1  40.693066 -73.999543   (40.69306580400007, -73.99954347299997)
# 2  40.694453 -73.969075   (40.69445324900005, -73.96907507999998)
# 3  40.816392 -73.895296  (40.816391847000034, -73.89529641399997)
# 4  40.789959 -73.945857   (40.78995927500005, -73.94585684099997)
#
# [5 rows x 35 columns]

# %%
min(nyc['CMPLNT_FR_DT']),max(nyc['CMPLNT_FR_DT']),nyc.shape
# Out:
# ('01/01/2018', '12/29/2018', (229, 35))

# %% [markdown]
# #### Boston Crime Data
# The Boston crime data set contains crime incident reports . The data comes from Analyze Boston, the City of Boston's open data hub, which is managed by the City of Boston's central data organization: The Citywide Analytics Team.  The original data set, which can be found at this link:
# https://data.boston.gov/dataset/crime-incident-reports-august-2015-to-date-source-new-system/resource/12cb3883-56f5-47de-afa5-3b1cf61b257b,
# contains over 496,986 observations and 17 variables. Each observation is an individual incident Boston Police Department officers responded to. It is important to note that this data set contains only incidents which were officially responded to by the Boston Police Department. Analyze Boston also clarifies that the data they provide is collected through the new crime incident report system.
#
# I am using this data set as a representation of the prevalence of crime in Boston neighborhoods. The original data set contains complaints from 1919 through 2020, but I have reduced the data set to complaints reported in 2018. This was done in the interest of making comparisons to New York City crime and adhereing to maximum file sizes accomodated by Github. Our pared-down dataset contains 98,888 complaints.

# %%
bos=pd.read_csv("https://raw.githubusercontent.com/jrossner/Coursera_Capstone/master/BOS_crime2018.csv", error_bad_lines=False)
bos.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP OFFENSE_DESCRIPTION  \
# 0      I192077559          3115  Investigate Person  INVESTIGATE PERSON
# 1      I192077332           619             Larceny  LARCENY ALL OTHERS
# 2      I192076660          2629          Harassment          HARASSMENT
# 3      I192075386          2629          Harassment          HARASSMENT
# 4      I192075335          3208       Property Lost  PROPERTY - MISSING
#
#   DISTRICT REPORTING_AREA SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH  \
# 0       B3            468      NaN  2018-04-30 09:00:00  2018      4
# 1      E18            496      NaN  2018-03-06 08:00:00  2018      3
# 2       E5            662      NaN  2018-10-31 12:00:00  2018     10
# 3       A1             96      NaN  2018-04-09 08:43:00  2018      4
# 4       D4            132      NaN  2018-01-01 00:00:00  2018      1
#
#   DAY_OF_WEEK  HOUR    UCR_PART            STREET        Lat       Long  \
# 0      Monday     9  Part Three       HAZLETON ST  42.279971 -71.095534
# 1     Tuesday     8    Part One     HYDE PARK AVE  42.269224 -71.120853
# 2   Wednesday    12    Part Two       PRIMROSE ST  42.290765 -71.130211
# 3      Monday     8    Part Two      ATLANTIC AVE  42.355264 -71.050988
# 4      Monday     0  Part Three  COMMONWEALTH AVE  42.353522 -71.072838
#
#                       Location
# 0  (42.27997063, -71.09553354)
# 1  (42.26922388, -71.12085347)
# 2  (42.29076521, -71.13021098)
# 3  (42.35526402, -71.05098788)
# 4  (42.35352153, -71.07283786)

# %%
min(bos["YEAR"]),max(bos["YEAR"]),bos.shape
# Out:
# (2018, 2018, (98888, 17))

# %% [markdown]
# The difference in our New York City and Boston crime data sets is immense, and may be due to recording procedures. According to the United States Census Bureau, the population of New York City in 2018 was almost 8.4 million people, while Boston's 2018 population was less than a tenth of that: just under 695 thousand people. There remains questions as to if Boston, a city with a population size of 10% of New York City's, really had 98,000 more criminal acts in 2018 than New York City, but that will not be a focal point of my investigation. I will be comparing what crimes are more common in New York City Neighborhoods compared to Boston Neighborhoods.
